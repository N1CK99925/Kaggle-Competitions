# %%
import pandas as pd
import numpy as np
data_train = pd.read_csv(r'C:\Users\Nick\OneDrive\Desktop\Kaggle\Housing price KAggle\train.csv')
data_test= pd.read_csv(r'C:\Users\Nick\OneDrive\Desktop\Kaggle\Housing price KAggle\test.csv')

# %%
data_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
data_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
print(data_train.isnull().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
print(data_train.isnull().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
print(data_train['Alley'].isnull())
data_train['Alley'].fillna('None',inplace=True)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 1455    True
# 1456    True
# 1457    True
# 1458    True
# 1459    True
# Name: Alley, Length: 1460, dtype: bool
# C:\Users\Nick\AppData\Local\Temp\ipykernel_15628\1528452657.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_train['Alley'].fillna('None',inplace=True)

# %%
data_test['Alley'].fillna('None', inplace=True)
# Out:
# C:\Users\Nick\AppData\Local\Temp\ipykernel_15628\3923070295.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test['Alley'].fillna('None', inplace=True)

# %%
data_train = pd.get_dummies(data_train)
data_test = pd.get_dummies(data_test)

# %%
data_test
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  \
# ...

# %%
x = data_train.drop(['SalePrice','Id'],axis=1)
y = data_train['SalePrice']
x_test = data_test.drop(['Id'],axis=1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score


model = RandomForestRegressor(n_estimators=100, random_state=1)
scores = cross_val_score(model, x, y, cv=5, scoring='neg_root_mean_squared_error')
print("CV RMSE:", -np.mean(scores))

model.fit(x, y)
y_pred = model.predict(x_test)
# Out:
# CV RMSE: 30195.44477896084
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 10
#       7 print("CV RMSE:", -np.mean(scores))
#       9 model.fit(x, y)
# ---> 10 y_pred = model.predict(x_test)
#
# File c:\Users\Nick\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:1066, in ForestRegressor.predict(self, X)
#    1064 check_is_fitted(self)
#    1065 # Check data
# -> 1066 X = self._validate_X_predict(X)
#    1068 # Assign chunk of trees to jobs
#    1069 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File c:\Users\Nick\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:638, in BaseForest._validate_X_predict(self, X)
#     635 else:
#     636     ensure_all_finite = True
# --> 638 X = validate_data(
#     639     self,
#     640     X,
#     641     dtype=DTYPE,
#     642     accept_sparse="csr",
#     643     reset=False,
# ...
